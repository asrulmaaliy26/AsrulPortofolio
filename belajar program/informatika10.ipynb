# %% [markdown]
# Berikut adalah **materi lengkap Bab 4: Variabel dan Operator** untuk Informatika Kelas 10, dirancang untuk **2 pertemuan**, berbasis praktik menggunakan **Console Chrome** dan bahasa **JavaScript**.
#
# ---
#
# # 📘 **Bab 4: Variabel dan Operator**
#
# ## 🎯 **Capaian Pembelajaran**
#
# Peserta didik memahami cara menggunakan variabel untuk menyimpan data dan mengolahnya menggunakan operator aritmatika, perbandingan, dan logika.
#
# ---
#
# ## 🧑‍🏫 **Pertemuan 1: Variabel dalam Pemrograman**
#
# ### 🧭 **Pendahuluan (5–10 menit)**
#
# Guru bertanya:
#
# > “Kalau kamu punya tempat untuk menyimpan uang, makanan, atau file, kira-kira di dunia pemrograman, tempat penyimpanannya disebut apa?”
#
# Jawabannya: **variabel**.
#
# ---
#
# ### 📚 **Isi Materi**
#
# #### 1. Apa Itu Variabel?
#
# * Tempat menyimpan data dalam program
# * Bisa diisi teks, angka, atau boolean
# * Dalam JavaScript, variabel dibuat dengan `let` atau `const`
#
#   ```javascript
#   let nama = "Siti";
#   let umur = 16;
#   let lulus = true;
#   ```
#
# #### 2. Aturan Penamaan Variabel
#
# * Tidak boleh pakai spasi
# * Tidak boleh diawali angka
# * Gunakan nama yang **bermakna**
#
#   ```javascript
#   let panjangPersegi = 10;
#   ```
#
# #### 3. Mengubah Nilai Variabel
#
# ```javascript
# let nilai = 80;
# nilai = 90;
# console.log(nilai); // 90
# ```
#
# ---
#
# ### 🧩 **Aktivitas Siswa**
#
# * **Latihan 1**: Buat variabel nama, kelas, dan jurusan. Cetak ke console.
# * **Latihan 2**: Buat variabel `nilaiTugas`, ubah nilainya, dan tampilkan ulang.
# * **Kuis cepat**:
#
#   * Valid atau tidak: `let 1nama = "Ali";`
#   * Valid atau tidak: `let nama_siswa = "Rina";`
#
# ---
#
# ### ✅ **Penutup**
#
# Guru simpulkan:
#
# > “Variabel membantu komputer menyimpan informasi yang bisa dipakai berulang kali.”
#
# **Refleksi ringan**:
#
# > “Apa manfaat memberi nama variabel yang bermakna daripada asal ketik?”
#
# ---
#
# ## 🧑‍🏫 **Pertemuan 2: Mengenal Operator dalam JavaScript**
#
# ### 🧭 **Pendahuluan (5–10 menit)**
#
# Guru bertanya:
#
# > “Kalau kamu punya dua angka, bagaimana cara kita suruh komputer menjumlahkannya?”
#
# ---
#
# ### 📚 **Isi Materi**
#
# #### 1. Operator Aritmatika
#
# * Tambah: `+`
# * Kurang: `-`
# * Kali: `*`
# * Bagi: `/`
# * Sisa bagi: `%`
#
# Contoh:
#
# ```javascript
# let a = 10;
# let b = 4;
# console.log(a + b); // 14
# console.log(a % b); // 2
# ```
#
# #### 2. Operator Perbandingan
#
# * Sama dengan: `==`
# * Tidak sama: `!=`
# * Lebih besar: `>`
# * Lebih kecil: `<`
#
# ```javascript
# let x = 5;
# console.log(x == 5); // true
# console.log(x > 10); // false
# ```
#
# #### 3. Operator Logika
#
# * DAN: `&&`
# * ATAU: `||`
# * TIDAK: `!`
#
# ```javascript
# let umur = 17;
# let lulus = true;
# console.log(umur >= 17 && lulus); // true
# ```
#
# ---
#
# ### 🧩 **Aktivitas Siswa**
#
# * **Latihan Aritmatika**: Buat variabel `panjang`, `lebar`, hitung luas
#
#   ```javascript
#   let panjang = 5;
#   let lebar = 3;
#   let luas = panjang * lebar;
#   console.log("Luas = " + luas);
#   ```
#
# * **Latihan Perbandingan**: Bandingkan nilai siswa dengan KKM
#
#   ```javascript
#   let nilai = 75;
#   console.log(nilai >= 70); // true
#   ```
#
# * **Latihan Logika**: Buat variabel usia & status lulus, lalu gabungkan dengan `&&`
#
# ---
#
# ### ✅ **Penutup**
#
# Guru menyimpulkan:
#
# > “Operator membuat kita bisa menghitung, membandingkan, dan membuat keputusan dalam kode.”
#
# **Refleksi mandiri:**
#
# > “Menurutmu, bagaimana cara komputer menentukan apakah siswa layak lulus atau tidak?”
#
# ---
#
# ## 📌 **Rekap Aktivitas Bab 4**
#
# | Pertemuan | Fokus                        | Aktivitas Praktik                                  |
# | --------- | ---------------------------- | -------------------------------------------------- |
# | 1         | Pengenalan variabel          | Buat, tampilkan, ubah nilai, dan validasi penamaan |
# | 2         | Operator aritmatika & logika | Hitung luas, bandingkan nilai, gabungkan kondisi   |
#
# ---
#
# Jika kamu mau, saya bisa bantu:
#
# * **Lembar soal evaluasi akhir bab**
# * **Lembar kerja siswa siap cetak (PDF / Google Docs)**
# * **Format rubrik penilaian mini tugas coding**
#
# Ingin saya bantu salah satu dari itu, atau lanjut ke **Bab 5: Input dan Output Program**?
#
#
# Berikut adalah **materi lengkap Bab 5: Input dan Output Program** untuk Informatika Kelas 10, disusun untuk **2 pertemuan**, dengan praktik sepenuhnya melalui **Console di Chrome** dan menggunakan bahasa **JavaScript**.
#
# ---
#
# # 📘 **Bab 5: Input dan Output Program**
#
# ## 🎯 **Capaian Pembelajaran**
#
# Peserta didik memahami cara membuat program interaktif dengan **mengambil input dari pengguna** dan **menampilkan hasil output** ke layar melalui Console. Dapat membuat program sederhana berbasis soal cerita, seperti menghitung luas dan keliling bangun datar.
#
# ---
#
# ## 🧑‍🏫 **Pertemuan 1: Memahami Input dan Output**
#
# ### 🧭 **Pendahuluan (5–10 menit)**
#
# Guru bertanya:
#
# > “Kalau kamu buka kalkulator di HP dan mengetik angka, apa yang terjadi kalau kamu tekan = ?”
#
# Ajak siswa menyadari bahwa:
#
# * Angka yang kita masukkan adalah **input**
# * Hasil yang muncul adalah **output**
#
# ---
#
# ### 📚 **Isi Materi**
#
# #### 1. Apa Itu Input dan Output?
#
# * **Input**: data yang dimasukkan oleh pengguna
# * **Output**: hasil yang ditampilkan oleh program
# * Di JavaScript:
#
#   * Input menggunakan `prompt()`
#   * Output menggunakan `console.log()`
#
# #### 2. Contoh Sederhana
#
# ```javascript
# let nama = prompt("Masukkan nama kamu:");
# console.log("Halo, " + nama + "!");
# ```
#
# #### 3. Input Angka
#
# * Input dari `prompt()` dianggap sebagai **string**
# * Agar bisa dihitung, harus dikonversi ke angka:
#
#   * `parseInt()` untuk bilangan bulat
#   * `parseFloat()` untuk bilangan desimal
#
# ```javascript
# let angka1 = parseInt(prompt("Masukkan angka pertama:"));
# let angka2 = parseInt(prompt("Masukkan angka kedua:"));
# let hasil = angka1 + angka2;
# console.log("Hasil penjumlahan: " + hasil);
# ```
#
# ---
#
# ### 🧩 **Aktivitas Siswa**
#
# * **Latihan 1**: Buat program yang menyapa pengguna berdasarkan input nama
# * **Latihan 2**: Minta input dua angka dan tampilkan hasil penjumlahan
# * **Diskusi mini**: Mengapa input dari prompt perlu diubah ke angka?
#
# ---
#
# ### ✅ **Penutup**
#
# Guru menyimpulkan:
#
# > “Tanpa input, program tidak bisa interaktif. Tanpa output, pengguna tidak tahu hasilnya.”
#
# **Refleksi ringan**:
#
# > “Apa bedanya menulis nilai langsung di kode dengan mengambilnya dari pengguna?”
#
# ---
#
# ## 🧑‍🏫 **Pertemuan 2: Studi Kasus – Hitung Luas dan Keliling Persegi Panjang**
#
# ### 🧭 **Pendahuluan (5–10 menit)**
#
# Guru menantang siswa:
#
# > “Bayangkan kamu membuat aplikasi untuk tukang bangunan menghitung luas tanah. Bagaimana cara program menerima ukuran panjang dan lebar?”
#
# ---
#
# ### 📚 **Isi Materi**
#
# #### 1. Studi Kasus: Hitung Luas dan Keliling
#
# * **Rumus**:
#
#   * Luas = panjang × lebar
#   * Keliling = 2 × (panjang + lebar)
#
# #### 2. Kode Program
#
# ```javascript
# let panjang = parseFloat(prompt("Masukkan panjang (cm):"));
# let lebar = parseFloat(prompt("Masukkan lebar (cm):"));
#
# let luas = panjang * lebar;
# let keliling = 2 * (panjang + lebar);
#
# console.log("Luas: " + luas + " cm²");
# console.log("Keliling: " + keliling + " cm");
# ```
#
# ---
#
# ### 🧩 **Aktivitas Siswa**
#
# * **Tugas utama**: Jalankan program di atas → ubah satuan (misal jadi meter)
#
# * **Tantangan tambahan**: Tambahkan output penilaian:
#
#   ```javascript
#   if (luas > 100) {
#     console.log("Luas tanah cukup besar");
#   } else {
#     console.log("Luas tanah standar");
#   }
#   ```
#
# * **Diskusi kelas**: Apakah program ini bisa dikembangkan untuk bidang lain?
#
# ---
#
# ### ✅ **Penutup**
#
# Guru menyimpulkan:
#
# > “Kita sudah membuat program kecil yang bisa menghitung berdasarkan input pengguna—sebuah bentuk nyata dari problem solving.”
#
# **Refleksi akhir**:
#
# > “Apa hal tersulit dan paling menarik saat membuat program hitung luas dan keliling tadi?”
#
# ---
#
# ## 📌 **Rekap Aktivitas Bab 5**
#
# | Pertemuan | Fokus                       | Aktivitas Praktik                                      |
# | --------- | --------------------------- | ------------------------------------------------------ |
# | 1         | Pengenalan input & output   | prompt() + console.log(), hitung penjumlahan sederhana |
# | 2         | Studi kasus luas & keliling | Input panjang & lebar → hitung & tampilkan hasil       |
#
# ---
#
# Jika kamu mau, saya bisa bantu:
#
# * **Lembar kerja siswa (LKS)** untuk bab ini
# * **Soal evaluasi akhir bab: pilihan ganda & coding ringan**
# * **Template tugas individu berbasis soal cerita**
#
# Ingin lanjut ke salah satu dari itu? Atau langsung ke **Bab 6: Percabangan dan Pengambilan Keputusan**?
#
#
# Berikut adalah **materi lengkap Bab 6: Percabangan dan Pengambilan Keputusan** untuk Informatika Kelas 10, disusun untuk **2 pertemuan** dan berfokus pada **praktik di Console Chrome** menggunakan **JavaScript**.
#
# ---
#
# # 📘 **Bab 6: Percabangan dan Pengambilan Keputusan**
#
# ## 🎯 **Capaian Pembelajaran**
#
# Peserta didik memahami konsep **pengambilan keputusan dalam program** menggunakan struktur **percabangan** (`if`, `else`, `else if`) dan dapat membuat program untuk menyelesaikan persoalan sehari-hari, seperti menentukan kategori usia atau menghitung diskon belanja.
#
# ---
#
# ## 🧑‍🏫 **Pertemuan 1: Struktur If dan Logika Sederhana**
#
# ### 🧭 **Pendahuluan (5–10 menit)**
#
# Guru mengajukan pertanyaan:
#
# > “Kalau kamu ingin belanja dan hanya punya uang Rp50.000, apakah kamu akan beli barang seharga Rp100.000?”
#
# Tanyakan:
#
# > “Bagaimana program bisa membuat keputusan seperti itu?”
#
# ---
#
# ### 📚 **Isi Materi**
#
# #### 1. Apa Itu Percabangan?
#
# * **Percabangan** adalah struktur logika yang memungkinkan program **mengambil keputusan berdasarkan kondisi tertentu**.
# * Gunakan `if`, `else`, dan `else if`.
#
# #### 2. Struktur Dasar
#
# ```javascript
# let usia = 17;
# if (usia >= 17) {
#   console.log("Kamu boleh membuat KTP");
# } else {
#   console.log("Belum cukup umur untuk KTP");
# }
# ```
#
# #### 3. Kondisi Ganda: `if - else if - else`
#
# ```javascript
# let nilai = 85;
# if (nilai >= 90) {
#   console.log("Nilai A");
# } else if (nilai >= 75) {
#   console.log("Nilai B");
# } else {
#   console.log("Nilai C");
# }
# ```
#
# ---
#
# ### 🧩 **Aktivitas Siswa**
#
# * **Latihan 1**: Masukkan usia, tampilkan kategori:
#
#   * `<12`: anak-anak
#   * `13–17`: remaja
#   * `18+`: dewasa
#
# ```javascript
# let umur = parseInt(prompt("Masukkan umur:"));
# if (umur < 12) {
#   console.log("Anak-anak");
# } else if (umur <= 17) {
#   console.log("Remaja");
# } else {
#   console.log("Dewasa");
# }
# ```
#
# * **Kuis cepat**: Apa hasilnya jika umur = 13? umur = 10?
#
# ---
#
# ### ✅ **Penutup**
#
# Guru menyimpulkan:
#
# > “Struktur `if` memungkinkan kita membuat program yang fleksibel dan cerdas, menyesuaikan dengan kondisi yang diberikan.”
#
# **Refleksi siswa**:
#
# > “Dalam kehidupan nyata, kapan kamu membuat keputusan seperti `if` dan `else`?”
#
# ---
#
# ## 🧑‍🏫 **Pertemuan 2: Studi Kasus – Program Diskon Belanja**
#
# ### 🧭 **Pendahuluan (5–10 menit)**
#
# Guru bertanya:
#
# > “Jika harga barang Rp200.000 dan ada diskon 10%, berapa yang harus dibayar? Tapi kalau cuma Rp50.000, tidak dapat diskon. Bagaimana program bisa menghitungnya?”
#
# ---
#
# ### 📚 **Isi Materi**
#
# #### 1. Studi Kasus: Hitung Diskon
#
# * Skenario:
#
#   * Jika belanja di atas Rp100.000 → diskon 10%
#   * Jika belanja di atas Rp200.000 → diskon 20%
#   * Jika kurang dari Rp100.000 → tanpa diskon
#
# #### 2. Kode Program:
#
# ```javascript
# let totalBelanja = parseFloat(prompt("Masukkan total belanja:"));
# let diskon = 0;
#
# if (totalBelanja > 200000) {
#   diskon = 0.2;
# } else if (totalBelanja > 100000) {
#   diskon = 0.1;
# } else {
#   diskon = 0;
# }
#
# let potongan = totalBelanja * diskon;
# let totalBayar = totalBelanja - potongan;
#
# console.log("Diskon: " + (diskon * 100) + "%");
# console.log("Total bayar: Rp" + totalBayar);
# ```
#
# ---
#
# ### 🧩 **Aktivitas Siswa**
#
# * **Latihan wajib**: Jalankan program di atas dengan berbagai nilai input
# * **Tugas modifikasi**: Tambahkan pesan jika tidak mendapat diskon
# * **Diskusi kelompok kecil**:
#
#   * Ubah logika → jika belanja > 300.000 dapat diskon 30%
#   * Tambahkan `console.log("Terima kasih telah berbelanja")` di akhir
#
# ---
#
# ### ✅ **Penutup**
#
# Guru menyimpulkan:
#
# > “Percabangan sangat penting dalam menyelesaikan masalah nyata. Hari ini kalian telah membuat program yang bisa mengambil keputusan berdasarkan data!”
#
# **Refleksi akhir**:
#
# > “Apa yang harus diperhatikan agar logika `if` bekerja sesuai yang kita maksud?”
#
# ---
#
# ## 📌 **Rekap Aktivitas Bab 6**
#
# | Pertemuan | Fokus                      | Aktivitas Praktik                                                       |
# | --------- | -------------------------- | ----------------------------------------------------------------------- |
# | 1         | Struktur if, else, else if | Program kategori usia, nilai siswa                                      |
# | 2         | Studi kasus diskon belanja | Input total belanja → hitung diskon dan total bayar + modifikasi logika |
#
# ---
#
# Jika kamu ingin, saya bisa bantu:
#
# * **Template soal coding dan soal cerita untuk evaluasi**
# * **Lembar kerja siswa Bab 6 (PDF / Docs)**
# * **Rubrik penilaian tugas diskon**
#
# Ingin dibantu ke salah satu itu? Atau lanjut ke **Bab 7: Perulangan (Looping)?**
#
#
# Berikut adalah **materi lengkap Bab 7: Perulangan (Looping)** untuk Informatika Kelas 10, disusun untuk **2 pertemuan**, fokus pada **praktik langsung di Console Chrome** menggunakan **JavaScript**.
#
# ---
#
# # 📘 **Bab 7: Perulangan (Looping)**
#
# ## 🎯 **Capaian Pembelajaran**
#
# Peserta didik memahami konsep perulangan (looping) dalam pemrograman, dapat menggunakan struktur `for` dan `while`, serta dapat menyelesaikan persoalan sederhana seperti mencetak pola dan tabel perkalian.
#
# ---
#
# ## 🧑‍🏫 **Pertemuan 1: Pengenalan Looping – For dan While**
#
# ### 🧭 **Pendahuluan (5–10 menit)**
#
# Guru bertanya:
#
# > “Kalau kamu disuruh mengetik 'Halo!' sebanyak 10 kali di console, mau ngetik satu-satu atau otomatis?”
#
# Tampilkan contoh kode tanpa loop:
#
# ```javascript
# console.log("Halo!");
# console.log("Halo!");
# console.log("Halo!");
# ```
#
# Lalu, bandingkan dengan versi loop:
#
# ```javascript
# for (let i = 0; i < 3; i++) {
#   console.log("Halo!");
# }
# ```
#
# ---
#
# ### 📚 **Isi Materi**
#
# #### 1. Apa Itu Perulangan?
#
# * Perulangan memungkinkan **menjalankan kode berulang kali** secara otomatis.
#
# #### 2. Struktur `for`
#
# ```javascript
# for (let i = 1; i <= 5; i++) {
#   console.log("Baris ke-" + i);
# }
# ```
#
# * `i = 1` → mulai dari 1
# * `i <= 5` → batas akhir
# * `i++` → naik 1 setiap kali
#
# #### 3. Struktur `while`
#
# ```javascript
# let i = 1;
# while (i <= 5) {
#   console.log("Angka: " + i);
#   i++;
# }
# ```
#
# * Gunakan `while` saat **kita tidak tahu pasti berapa kali akan mengulang**
#
# ---
#
# ### 🧩 **Aktivitas Siswa**
#
# * **Latihan 1**: Cetak “Saya semangat belajar!” sebanyak 7 kali
# * **Latihan 2**: Ubah kode `for` menjadi `while`
# * **Kuis**:
#
#   * Apa perbedaan `for` dan `while`?
#   * Apa yang terjadi jika lupa `i++` di dalam `while`?
#
# ---
#
# ### ✅ **Penutup**
#
# Guru menyimpulkan:
#
# > “Looping membantu kita bekerja lebih efisien—cukup satu baris untuk mencetak 100 kali!”
#
# **Refleksi ringan:**
#
# > “Kapan kamu butuh pengulangan dalam kehidupan nyata?”
#
# ---
#
# ## 🧑‍🏫 **Pertemuan 2: Studi Kasus – Tabel Perkalian dan Pola**
#
# ### 🧭 **Pendahuluan (5–10 menit)**
#
# Guru bertanya:
#
# > “Bagaimana cara membuat program yang mencetak tabel perkalian 1–10 secara otomatis?”
#
# ---
#
# ### 📚 **Isi Materi**
#
# #### 1. Tabel Perkalian 1–10
#
# ```javascript
# for (let i = 1; i <= 10; i++) {
#   console.log("5 x " + i + " = " + (5 * i));
# }
# ```
#
# * Ubah 5 menjadi input pengguna:
#
# ```javascript
# let angka = parseInt(prompt("Masukkan angka perkalian:"));
# for (let i = 1; i <= 10; i++) {
#   console.log(angka + " x " + i + " = " + (angka * i));
# }
# ```
#
# #### 2. Pola Segitiga Bintang
#
# ```javascript
# let tinggi = 5;
# for (let i = 1; i <= tinggi; i++) {
#   let baris = "";
#   for (let j = 1; j <= i; j++) {
#     baris += "*";
#   }
#   console.log(baris);
# }
# ```
#
# * Penjelasan: **Loop di dalam loop** (nested loop)
#
# ---
#
# ### 🧩 **Aktivitas Siswa**
#
# * **Latihan utama**:
#
#   * Buat program cetak tabel perkalian dari input
#   * Ubah program pola bintang jadi segitiga terbalik
#
# * **Tantangan**:
#
#   * Tambahkan kondisi: jika `i` kelipatan 5, tampilkan tulisan “– ini kelipatan 5!”
#
# ```javascript
# for (let i = 1; i <= 20; i++) {
#   if (i % 5 === 0) {
#     console.log(i + " - ini kelipatan 5!");
#   } else {
#     console.log(i);
#   }
# }
# ```
#
# ---
#
# ### ✅ **Penutup**
#
# Guru menyimpulkan:
#
# > “Looping bukan hanya membuat pekerjaan berulang jadi mudah, tapi juga membuka pintu untuk membangun program dinamis seperti kalkulator, permainan, bahkan simulasi!”
#
# **Refleksi akhir**:
#
# > “Apa yang paling menantang dalam membuat program perulangan hari ini?”
#
# ---
#
# ## 📌 **Rekap Aktivitas Bab 7**
#
# | Pertemuan | Fokus                        | Aktivitas Praktik                                                   |
# | --------- | ---------------------------- | ------------------------------------------------------------------- |
# | 1         | Pengenalan `for` dan `while` | Cetak teks berulang, bandingkan struktur, latihan pengulangan dasar |
# | 2         | Studi kasus looping          | Tabel perkalian, pola bintang, kelipatan, input & nested loop       |
#
# ---
#
# Jika kamu mau, saya bisa bantu:
#
# * **Lembar kerja siswa bab 7 (PDF / Docs)**
# * **Tugas individu dengan rubrik penilaian looping**
# * **Latihan mandiri berbasis soal cerita looping**
#
# Ingin dibantu salah satu? Atau lanjut ke **Bab 8: Struktur Data Sederhana (Array/List)?**
#
#
# Berikut adalah **materi lengkap Bab 8: Struktur Data Sederhana (Array/List)** untuk Informatika Kelas 10, disusun untuk **2 pertemuan**, dengan praktik langsung menggunakan **Console di Chrome** dan **JavaScript**.
#
# ---
#
# # 📘 **Bab 8: Struktur Data Sederhana – Array**
#
# ## 🎯 **Capaian Pembelajaran**
#
# Peserta didik memahami cara menyimpan dan mengakses banyak data menggunakan **array (list)**, serta dapat mengolah data tersebut menggunakan kode JavaScript.
#
# ---
#
# ## 🧑‍🏫 **Pertemuan 1: Pengenalan Array dan Akses Data**
#
# ### 🧭 **Pendahuluan (5–10 menit)**
#
# Guru bertanya:
#
# > “Kalau kamu punya 5 nilai ujian, lebih mudah disimpan satu per satu, atau dalam satu wadah?”
#
# Tunjukkan:
#
# ```javascript
# let nilai1 = 80;
# let nilai2 = 85;
# let nilai3 = 78;
# ```
#
# Bandingkan dengan array:
#
# ```javascript
# let nilai = [80, 85, 78];
# ```
#
# ---
#
# ### 📚 **Isi Materi**
#
# #### 1. Apa Itu Array?
#
# * Array adalah **kumpulan data** dalam satu variabel
# * Ditulis dengan **tanda kurung siku `[]`**
# * Contoh:
#
#   ```javascript
#   let buah = ["apel", "jeruk", "mangga"];
#   ```
#
# #### 2. Akses Elemen Array
#
# * Elemen diakses berdasarkan **indeks** (dimulai dari 0)
#
#   ```javascript
#   console.log(buah[0]); // "apel"
#   console.log(buah[2]); // "mangga"
#   ```
#
# #### 3. Menambah & Mengubah Isi Array
#
# ```javascript
# buah[1] = "pisang";        // ubah jeruk jadi pisang
# buah.push("durian");       // tambahkan durian
# ```
#
# ---
#
# ### 🧩 **Aktivitas Siswa**
#
# * **Latihan 1**: Buat array `hobi` berisi 3 hobi
# * **Latihan 2**: Tampilkan hobi ke-2
# * **Tantangan**: Tambahkan 1 hobi lagi menggunakan `.push()`, lalu tampilkan semua hobi dengan:
#
#   ```javascript
#   console.log(hobi);
#   ```
#
# ---
#
# ### ✅ **Penutup**
#
# Guru menyimpulkan:
#
# > “Array membuat program lebih efisien ketika kita perlu menyimpan banyak data. Kita bisa mengakses, mengubah, dan menambah data dengan mudah.”
#
# **Refleksi siswa**:
#
# > “Apa bedanya menyimpan data satu per satu dengan menggunakan array?”
#
# ---
#
# ## 🧑‍🏫 **Pertemuan 2: Studi Kasus – Nilai Ujian dan Daftar Belanja**
#
# ### 🧭 **Pendahuluan (5–10 menit)**
#
# Guru bertanya:
#
# > “Kalau kamu punya daftar belanja berisi 10 barang, bagaimana cara menampilkannya satu per satu ke layar?”
#
# ---
#
# ### 📚 **Isi Materi**
#
# #### 1. Menampilkan Isi Array dengan Loop
#
# ```javascript
# let belanja = ["beras", "gula", "minyak", "sabun"];
# for (let i = 0; i < belanja.length; i++) {
#   console.log(belanja[i]);
# }
# ```
#
# #### 2. Studi Kasus: Hitung Rata-rata Nilai
#
# ```javascript
# let nilai = [80, 90, 70, 85, 75];
# let total = 0;
#
# for (let i = 0; i < nilai.length; i++) {
#   total += nilai[i];
# }
#
# let rata2 = total / nilai.length;
# console.log("Rata-rata nilai: " + rata2);
# ```
#
# ---
#
# ### 🧩 **Aktivitas Siswa**
#
# * **Tugas utama**: Buat array `nilaiTugas` dan tampilkan total dan rata-rata
# * **Modifikasi mandiri**:
#
#   * Tambahkan kondisi: jika ada nilai < 75, tampilkan “Ada yang perlu remedial”
#
#   ```javascript
#   for (let i = 0; i < nilai.length; i++) {
#     if (nilai[i] < 75) {
#       console.log("Nilai ke-" + (i+1) + " perlu remedial");
#     }
#   }
#   ```
# * **Diskusi**: Array mana yang cocok untuk disimpan: nama teman, tinggi badan, status lulus?
#
# ---
#
# ### ✅ **Penutup**
#
# Guru menyimpulkan:
#
# > “Array memudahkan kita menyimpan banyak data dan menganalisisnya secara efisien dengan bantuan perulangan.”
#
# **Refleksi akhir**:
#
# > “Apa kelebihan menyimpan nilai ujian dalam array dibandingkan menyimpannya satu per satu?”
#
# ---
#
# ## 📌 **Rekap Aktivitas Bab 8**
#
# | Pertemuan | Fokus                       | Aktivitas Praktik                                       |
# | --------- | --------------------------- | ------------------------------------------------------- |
# | 1         | Dasar array dan akses data  | Buat array hobi, akses elemen, ubah & tambah data       |
# | 2         | Looping array & studi kasus | Tabel belanja, nilai ujian → total, rata-rata, remedial |
#
# ---
#
# Jika kamu ingin, saya bisa bantu:
#
# * **LKS (lembar kerja siswa) dalam PDF/Docs**
# * **Tugas evaluasi berbasis soal cerita (nilai siswa, belanja)**
# * **Rubrik penilaian array & rata-rata nilai**
#
# Ingin saya bantu ke salah satu dari itu? Atau langsung lanjut ke **Bab 9: Debugging dan Penanganan Error**?
#
#
# Berikut adalah **materi lengkap Bab 9: Debugging dan Penanganan Error** untuk Informatika Kelas 10, dirancang untuk **2 pertemuan**, dengan fokus praktik melalui **Console di Chrome** menggunakan **JavaScript**.
#
# ---
#
# # 📘 **Bab 9: Debugging dan Penanganan Error**
#
# ## 🎯 **Capaian Pembelajaran**
#
# Peserta didik mengenali jenis-jenis kesalahan dalam pemrograman (syntax, runtime, dan logic error), serta memahami cara melakukan **debugging** secara sederhana untuk memperbaiki program yang tidak berjalan sesuai harapan.
#
# ---
#
# ## 🧑‍🏫 **Pertemuan 1: Jenis-jenis Error dalam Pemrograman**
#
# ### 🧭 **Pendahuluan (5–10 menit)**
#
# Guru bertanya:
#
# > “Pernah nggak kalian nulis kode lalu muncul warna merah dan pesan aneh di Console? Itu namanya error!”
#
# Tunjukkan contoh error langsung:
#
# ```javascript
# console.log("Halo dunia);
# ```
#
# ---
#
# ### 📚 **Isi Materi**
#
# #### 1. Apa Itu Error?
#
# * Kesalahan dalam kode program yang menyebabkan program tidak berjalan sebagaimana mestinya.
#
# #### 2. Tiga Jenis Error:
#
# 1. **Syntax Error**
#    ➤ Kesalahan aturan penulisan kode
#    Contoh:
#
#    ```javascript
#    console.log("Halo dunia); // tanda kutip tidak ditutup
#    ```
# 2. **Runtime Error**
#    ➤ Program crash saat dijalankan
#    Contoh:
#
#    ```javascript
#    let x = prompt("Masukkan angka:");
#    console.log(x * y); // y belum dideklarasikan
#    ```
# 3. **Logic Error**
#    ➤ Program jalan, tapi hasilnya salah
#    Contoh:
#
#    ```javascript
#    let harga = 100000;
#    let diskon = 10;
#    let bayar = harga + (harga * diskon / 100); // salah, seharusnya dikurang
#    ```
#
# ---
#
# ### 🧩 **Aktivitas Siswa**
#
# * **Latihan 1**: Guru berikan 3 kode error, siswa identifikasi jenisnya
# * **Latihan 2**: Siswa membuat 1 contoh syntax error & 1 logic error sendiri
# * **Diskusi mini**: Apa akibat error jika tidak segera diketahui?
#
# ---
#
# ### ✅ **Penutup**
#
# Guru menyimpulkan:
#
# > “Menemukan dan memperbaiki kesalahan adalah bagian penting dari belajar coding. Bahkan programmer profesional pun masih sering mengalami error.”
#
# **Refleksi siswa:**
#
# > “Error mana yang paling mudah ditemukan, dan mana yang paling membingungkan?”
#
# ---
#
# ## 🧑‍🏫 **Pertemuan 2: Teknik Debugging Dasar**
#
# ### 🧭 **Pendahuluan (5–10 menit)**
#
# Guru bertanya:
#
# > “Kalau program kamu error, apa yang kamu lakukan? Apakah langsung panik?”
#
# Lalu arahkan:
#
# > “Kita bisa belajar cara menelusuri kesalahan seperti detektif!”
#
# ---
#
# ### 📚 **Isi Materi**
#
# #### 1. Apa Itu Debugging?
#
# * Proses **mencari dan memperbaiki kesalahan** (bug) dalam kode program
#
# #### 2. Teknik Debugging Dasar:
#
# 1. **Baca pesan error di Console**
#
#    * Console akan menunjukkan baris mana yang error
#
# 2. **Gunakan `console.log()` untuk melacak nilai**
#
#    * Cetak nilai variabel satu per satu
#
#    Contoh:
#
#    ```javascript
#    let harga = 100000;
#    let diskon = 20;
#    console.log("Harga awal: " + harga);
#    console.log("Diskon: " + diskon);
#    let bayar = harga - (harga * diskon / 100);
#    console.log("Total bayar: " + bayar);
#    ```
#
# 3. **Periksa nama variabel dan tanda baca**
#
#    * Sering terjadi typo atau lupa titik koma/kutip
#
# ---
#
# ### 🧩 **Aktivitas Siswa**
#
# * **Tugas utama**: Guru beri kode yang error → siswa perbaiki
#   Contoh kode:
#
#   ```javascript
#   let harga = 150000
#   let diskon = 10
#   bayar = harga - harga * diskon / 100;
#   console.log("Bayar: Rp" + bayar;
#   ```
#
# * **Tantangan**:
#
#   * Tambahkan `console.log()` di setiap langkah untuk melihat isi variabel
#   * Perbaiki 3 kesalahan (syntax dan logic)
#
# * **Diskusi akhir**: Kenapa `console.log()` bisa sangat membantu saat debugging?
#
# ---
#
# ### ✅ **Penutup**
#
# Guru menyimpulkan:
#
# > “Debugging adalah keahlian penting. Semakin sering kita mencari dan memperbaiki bug, semakin mahir kita dalam berpikir logis dan teliti.”
#
# **Refleksi akhir**:
#
# > “Apa langkah pertamamu saat program yang kamu buat tidak berjalan?”
#
# ---
#
# ## 📌 **Rekap Aktivitas Bab 9**
#
# | Pertemuan | Fokus                  | Aktivitas Praktik                                            |
# | --------- | ---------------------- | ------------------------------------------------------------ |
# | 1         | Jenis-jenis error      | Identifikasi error, buat contoh sendiri                      |
# | 2         | Teknik debugging dasar | Perbaiki kode error, gunakan `console.log()` untuk pelacakan |
#
# ---
#
# Jika kamu mau, saya bisa bantu:
#
# * **Lembar soal latihan debugging (3 jenis error campuran)**
# * **Lembar kerja siswa (LKS) Bab 9 PDF/Docs**
# * **Rubrik penilaian debugging dan logika koreksi**
#
# Ingin saya bantu salah satu dari itu? Atau lanjut ke **Bab 10: Pengenalan JavaScript Lanjutan**?
#
#
# Berikut adalah **materi lengkap Bab 10: Pengenalan JavaScript** untuk Informatika Kelas 10, disusun untuk **2 pertemuan**, dengan fokus praktik melalui **Console di Chrome**, sebagai penguatan dan pematangan konsep JavaScript dasar sebelum masuk ke pengembangan web.
#
# ---
#
# # 📘 **Bab 10: Pengenalan JavaScript**
#
# ## 🎯 **Capaian Pembelajaran**
#
# Peserta didik memahami dasar-dasar sintaks JavaScript, mampu menggunakan variabel, operator, percabangan, dan perulangan dalam satu alur logika, serta mampu menggabungkan elemen tersebut ke dalam mini program.
#
# ---
#
# ## 🧑‍🏫 **Pertemuan 1: Sintaks Dasar dan Struktur Umum JavaScript**
#
# ### 🧭 **Pendahuluan (5–10 menit)**
#
# Guru bertanya:
#
# > “Kalau kalian pernah lihat tombol 'klik di sini' di situs web, siapa yang membuat tombol itu bisa jalan? Jawabannya: JavaScript.”
#
# ---
#
# ### 📚 **Isi Materi**
#
# #### 1. Apa Itu JavaScript?
#
# * JavaScript adalah **bahasa pemrograman utama untuk web**
# * Digunakan untuk membuat halaman **interaktif dan dinamis**
# * Dapat ditulis dan dijalankan langsung di Console browser
#
# #### 2. Struktur Dasar JavaScript
#
# * **Perintah dijalankan dari atas ke bawah**
# * **Komentar kode** menggunakan `//` atau `/* ... */`
#
# ```javascript
# // Ini komentar
# let nama = "Aldi";
# console.log("Halo, " + nama);
# ```
#
# #### 3. Ringkasan Ulang Elemen Dasar:
#
# * Variabel: `let`, `const`
# * Tipe data: `string`, `number`, `boolean`
# * Operator: `+`, `-`, `*`, `/`, `==`, `&&`
# * Percabangan: `if`, `else`, `else if`
# * Perulangan: `for`, `while`
#
# ---
#
# ### 🧩 **Aktivitas Siswa**
#
# * **Latihan 1**: Gabungkan semua yang telah dipelajari
#
#   * Buat program menyapa nama, menghitung usia dari tahun lahir, dan menentukan kategori usia
#
#   Contoh:
#
#   ```javascript
#   let nama = prompt("Masukkan nama:");
#   let tahunLahir = prompt("Masukkan tahun lahir:");
#   let usia = 2025 - tahunLahir;
#
#   console.log("Hai " + nama + ", usia kamu " + usia + " tahun");
#
#   if (usia >= 17) {
#     console.log("Kamu sudah remaja akhir");
#   } else {
#     console.log("Masih remaja muda");
#   }
#   ```
#
# * **Diskusi kelompok**: Apa saja hal-hal menarik yang bisa dibuat dari kombinasi if + variabel + prompt?
#
# ---
#
# ### ✅ **Penutup**
#
# Guru menyimpulkan:
#
# > “JavaScript adalah alat utama dalam dunia web dan program interaktif. Kalian sudah punya bekal lengkap untuk membuat program logika.”
#
# **Refleksi siswa:**
#
# > “Seberapa yakin kamu membuat program logika sendiri tanpa melihat catatan?”
#
# ---
#
# ## 🧑‍🏫 **Pertemuan 2: Mini Proyek JavaScript di Console**
#
# ### 🧭 **Pendahuluan (5–10 menit)**
#
# Guru memberi tantangan:
#
# > “Hari ini kamu akan jadi developer mini! Ayo buat program mini sesuai alur logikamu.”
#
# ---
#
# ### 📚 **Isi Materi**
#
# #### 1. Pilihan Mini Proyek
#
# Siswa memilih salah satu:
#
# 1. **Kalkulator Diskon Cerdas**
#
#    * Input harga & diskon → output total bayar
#    * Bonus: tampilkan komentar jika diskon besar (> 50%)
#
# 2. **Kalkulator Nilai Ujian**
#
#    * Input nilai → tampilkan predikat A/B/C
#    * Gunakan `if - else if - else`
#
# 3. **Tebak Umur**
#
#    * Input tahun lahir → hitung usia
#    * Jika usia < 10, tampilkan “Anak-anak”, dst.
#
# ---
#
# ### 🧩 **Aktivitas Siswa**
#
# * **Langkah 1**: Pilih proyek
# * **Langkah 2**: Buat alur logika di kertas (pseudocode)
# * **Langkah 3**: Tulis kodenya di Console Chrome
# * **Langkah 4**: Tes dengan berbagai input
# * **Langkah 5 (opsional)**: Tukar kode dengan teman → tes silang
#
# ---
#
# ### ✅ **Penutup**
#
# Guru memberikan pujian:
#
# > “Kalian baru saja menyusun dan menjalankan mini program sendiri, seperti developer sungguhan!”
#
# **Refleksi akhir:**
#
# > “Apa hal paling kamu banggakan dari program yang kamu buat hari ini?”
#
# ---
#
# ## 📌 **Rekap Aktivitas Bab 10**
#
# | Pertemuan | Fokus                             | Aktivitas Praktik                                                 |
# | --------- | --------------------------------- | ----------------------------------------------------------------- |
# | 1         | Struktur umum & logika JavaScript | Gabungan variabel + operator + if + prompt                        |
# | 2         | Mini proyek pribadi               | Proyek: diskon, nilai, atau umur + debugging dan uji coba mandiri |
#
# ---
#
# Jika kamu ingin, saya bisa bantu:
#
# * **Template penilaian mini proyek JavaScript**
# * **Formulir refleksi siswa (format PDF/Docs)**
# * **Soal pilihan ganda bab 10 (penguatan sintaks)**
#
# Ingin saya bantu salah satu? Atau lanjut ke **Bab 11: Dasar-dasar Pengembangan Web**?
#
#
# Berikut adalah **materi lengkap Bab 11: Dasar-dasar Pengembangan Web** untuk Informatika Kelas 10, dirancang untuk **2 pertemuan**. Pendekatan tetap berbasis praktik, namun kini siswa mulai mengenal **HTML, CSS, dan integrasinya dengan JavaScript**, langsung melalui browser (tanpa perlu install editor).
#
# ---
#
# # 📘 **Bab 11: Dasar-dasar Pengembangan Web**
#
# ## 🎯 **Capaian Pembelajaran**
#
# Peserta didik memahami struktur dasar halaman web menggunakan HTML dan CSS, serta mampu menambahkan interaktivitas sederhana menggunakan JavaScript melalui Console.
#
# ---
#
# ## 🧑‍🏫 **Pertemuan 1: Struktur HTML dan Styling CSS Dasar**
#
# ### 🧭 **Pendahuluan (5–10 menit)**
#
# Guru bertanya:
#
# > “Apa yang sebenarnya terjadi saat kamu membuka halaman web seperti Wikipedia atau Instagram?”
#
# Tampilkan struktur dasar halaman HTML melalui fitur *Inspect Element* di Chrome.
#
# ---
#
# ### 📚 **Isi Materi**
#
# #### 1. Apa Itu HTML?
#
# * **HTML (HyperText Markup Language)**: bahasa untuk **membangun struktur halaman web**
# * Elemen HTML ditulis menggunakan **tag**:
#
#   ```html
#   <h1>Selamat Datang</h1>
#   <p>Ini adalah paragraf</p>
#   ```
#
# #### 2. Struktur Dasar HTML
#
# ```html
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>Halaman Pertamaku</title>
#   </head>
#   <body>
#     <h1>Halo Dunia!</h1>
#     <p>Belajar membuat web</p>
#   </body>
# </html>
# ```
#
# #### 3. Apa Itu CSS?
#
# * **CSS (Cascading Style Sheets)**: untuk mengatur **tampilan halaman web**
# * Dapat mengubah warna, ukuran, jarak, dll.
# * Contoh:
#
#   ```html
#   <style>
#     body {
#       background-color: lightblue;
#     }
#     h1 {
#       color: darkblue;
#       font-family: Arial;
#     }
#   </style>
#   ```
#
# ---
#
# ### 🧩 **Aktivitas Siswa**
#
# * **Latihan mandiri**: Buka Chrome → klik kanan → Inspect → klik tab *Elements* → ubah teks `<h1>` langsung
# * **Ketik HTML di Live Editor** (misalnya: [https://jsfiddle.net](https://jsfiddle.net) atau [https://codepen.io](https://codepen.io))
#
#   * Buat halaman dengan judul, paragraf, dan ubah warnanya
#
# ---
#
# ### ✅ **Penutup**
#
# Guru menyimpulkan:
#
# > “HTML adalah fondasi, CSS adalah dekorasi. Hari ini kamu sudah menyusun kerangka halaman web sendiri!”
#
# **Refleksi siswa:**
#
# > “Apa bagian dari HTML/CSS yang terasa paling menarik untukmu?”
#
# ---
#
# ## 🧑‍🏫 **Pertemuan 2: Menghubungkan HTML, CSS, dan JavaScript**
#
# ### 🧭 **Pendahuluan (5–10 menit)**
#
# Guru bertanya:
#
# > “HTML bisa bikin halaman web, CSS mempercantik. Tapi... siapa yang bikin tombol bisa diklik dan berubah warna?”
#
# Jawaban: **JavaScript!**
#
# ---
#
# ### 📚 **Isi Materi**
#
# #### 1. Menulis JavaScript di HTML
#
# * Tambahkan dalam tag `<script>`:
#
#   ```html
#   <script>
#     console.log("Halaman dimuat!");
#   </script>
#   ```
#
# #### 2. Interaksi via Tombol
#
# * Buat tombol yang bisa memberi alert:
#
#   ```html
#   <button onclick="sapa()">Klik Aku!</button>
#
#   <script>
#     function sapa() {
#       alert("Halo, selamat datang!");
#     }
#   </script>
#   ```
#
# #### 3. Memanipulasi Konten HTML (DOM)
#
# ```html
# <p id="pesan">Belum diklik</p>
# <button onclick="ubahTeks()">Klik</button>
#
# <script>
#   function ubahTeks() {
#     document.getElementById("pesan").innerText = "Sudah diklik!";
#   }
# </script>
# ```
#
# ---
#
# ### 🧩 **Aktivitas Siswa**
#
# * **Latihan mandiri**:
#
#   * Buat halaman web sederhana berisi:
#
#     * Judul halaman
#     * Tombol interaktif
#     * Paragraf yang berubah saat tombol ditekan
#
# * **Tantangan kelompok**:
#
#   * Tambahkan logika: jika diklik dua kali, tampilkan pesan berbeda
#   * Gunakan CSS untuk memberi warna latar yang berubah setelah tombol ditekan
#
# ---
#
# ### ✅ **Penutup**
#
# Guru menyimpulkan:
#
# > “Sekarang kamu sudah tahu bagaimana HTML, CSS, dan JavaScript bekerja sama untuk membentuk web modern yang kita pakai sehari-hari.”
#
# **Refleksi siswa:**
#
# > “Setelah membuat tombol interaktif, apa fitur lain yang ingin kamu tambahkan ke halaman webmu?”
#
# ---
#
# ## 📌 **Rekap Aktivitas Bab 11**
#
# | Pertemuan | Fokus                     | Aktivitas Praktik                                                         |
# | --------- | ------------------------- | ------------------------------------------------------------------------- |
# | 1         | Struktur HTML & CSS dasar | Menulis tag HTML, styling warna dan font, modifikasi tampilan via Inspect |
# | 2         | Gabungan HTML + JS        | Tombol interaktif, manipulasi teks via DOM                                |
#
# ---
#
# Jika kamu ingin, saya bisa bantu:
#
# * **Template proyek mini halaman web interaktif**
# * **Lembar kerja siswa Bab 11 (HTML/CSS/JS)**
# * **Rubrik penilaian proyek web sederhana**
#
# Ingin dibantu salah satu? Atau lanjut ke **Bab 12: Proyek Akhir – Problem Solving dengan Kode**?
#
#
# Berikut adalah **materi lengkap Bab 12: Proyek Akhir – Problem Solving dengan Kode** untuk Informatika Kelas 10. Bab ini merupakan **penutup**, disusun untuk **2 pertemuan**, dan berfokus pada **mengaplikasikan semua materi dari Bab 1–11** ke dalam **proyek mini berbasis soal cerita**.
#
# ---
#
# # 📘 **Bab 12: Proyek Akhir – Problem Solving dengan Kode**
#
# ## 🎯 **Capaian Pembelajaran**
#
# Peserta didik mampu menerapkan konsep-konsep informatika yang telah dipelajari untuk **memecahkan masalah nyata menggunakan kode**, dengan logika yang tersusun jelas, efisien, dan interaktif.
#
# ---
#
# ## 🧑‍🏫 **Pertemuan 1: Merancang Logika Program dari Soal Cerita**
#
# ### 🧭 **Pendahuluan (5–10 menit)**
#
# Guru bertanya:
#
# > “Bayangkan kamu bekerja di minimarket, dan harus menghitung harga akhir pembelian pelanggan dengan diskon. Bisakah kamu membuat program yang melakukan itu?”
#
# ---
#
# ### 📚 **Isi Materi**
#
# #### 1. Langkah-langkah Problem Solving:
#
# 1. **Pahami soal cerita**
# 2. **Tentukan input & output**
# 3. **Buat logika alur (flow)**:
#
#    * Percabangan? Perulangan? Variabel?
# 4. **Tulis kode**
# 5. **Uji dan perbaiki (debug)**
#
# ---
#
# #### 2. Contoh Soal Cerita:
#
# > "Seorang pelanggan membeli barang seharga Rp150.000. Jika belanja di atas Rp200.000 mendapat diskon 20%, di atas Rp100.000 diskon 10%. Hitung total bayar."
#
# ---
#
# ### 🧩 **Aktivitas Siswa**
#
# * **Tugas kelompok kecil**:
#
#   1. Pahami soal
#   2. Buat pseudocode (tulisan logika langkah demi langkah)
#   3. Tentukan input & output
#   4. Tentukan struktur (variabel, if, perhitungan)
#
# Contoh pseudocode:
#
# ```
# - Input total belanja
# - Jika belanja > 200.000 → diskon 20%
# - Jika belanja > 100.000 → diskon 10%
# - Hitung total bayar
# - Tampilkan hasil
# ```
#
# ---
#
# ### ✅ **Penutup**
#
# Guru menyimpulkan:
#
# > “Sebelum membuat program, yang paling penting adalah menyusun logika yang benar.”
#
# **Refleksi ringan**:
#
# > “Bagian mana yang paling kamu nikmati saat menyusun alur program?”
#
# ---
#
# ## 🧑‍🏫 **Pertemuan 2: Menulis dan Menyempurnakan Program Mini**
#
# ### 🧭 **Pendahuluan (5–10 menit)**
#
# Guru membuka dengan:
#
# > “Hari ini kita akan membuktikan bahwa kalian sudah bisa menyusun program nyata untuk menyelesaikan persoalan sehari-hari.”
#
# ---
#
# ### 📚 **Isi Materi**
#
# #### 1. Contoh Penyelesaian Program Diskon:
#
# ```javascript
# let belanja = parseFloat(prompt("Masukkan total belanja:"));
# let diskon = 0;
#
# if (belanja > 200000) {
#   diskon = 0.2;
# } else if (belanja > 100000) {
#   diskon = 0.1;
# }
#
# let potongan = belanja * diskon;
# let totalBayar = belanja - potongan;
#
# console.log("Diskon: " + (diskon * 100) + "%");
# console.log("Total bayar: Rp" + totalBayar);
# ```
#
# ---
#
# ### 🧩 **Aktivitas Siswa**
#
# * **Tugas individu**: Pilih salah satu proyek:
#
#   1. **Kalkulator diskon pembelian**
#   2. **Penilaian nilai akhir siswa**
#   3. **Tebak usia dari tahun lahir**
#   4. **Daftar belanja dengan total harga**
#
# * **Langkah kerja**:
#
#   * Rancang alur logika sendiri
#   * Kembangkan dalam Console Chrome
#   * Tambahkan komentar dan `console.log()` untuk penjelasan tiap bagian
#
# * **Presentasi mini (jika sempat)**: Siswa tampilkan kodenya dan menjelaskan logikanya
#
# ---
#
# ### ✅ **Penutup**
#
# Guru memberi apresiasi:
#
# > “Kalian sudah membuktikan bahwa kalian bisa menyelesaikan persoalan menggunakan logika dan kode. Selamat, kalian telah menjadi problem solver digital!”
#
# **Refleksi akhir kelas:**
#
# > “Apa rencana atau ide program sederhana yang ingin kamu buat sendiri setelah ini?”
#
# ---
#
# ## 📌 **Rekap Aktivitas Bab 12**
#
# | Pertemuan | Fokus                        | Aktivitas Praktik                                                  |
# | --------- | ---------------------------- | ------------------------------------------------------------------ |
# | 1         | Penyusunan logika & analisis | Pseudocode, alur input/output dari soal cerita                     |
# | 2         | Implementasi dan debugging   | Coding proyek mini, uji coba, perbaikan, dan (opsional) presentasi |
#
# ---
#
# ## 📝 Rekomendasi Penilaian Bab 12:
#
# | Aspek                          | Bobot |
# | ------------------------------ | ----- |
# | Penyusunan logika (pseudocode) | 25%   |
# | Fungsi program berjalan        | 35%   |
# | Kebersihan kode & struktur     | 20%   |
# | Presentasi/pemahaman           | 20%   |
#
# ---
#
# Jika kamu ingin, saya bisa bantu:
#
# * **Template rubrik penilaian proyek akhir**
# * **Form refleksi siswa**
# * **Lembar soal cerita tambahan untuk latihan mandiri**
#
# Dengan ini, seluruh **12 Bab Informatika Kelas 10** telah selesai.
# Ingin saya bantu susun dokumen rekap silabus atau ringkasan 12 babnya?
